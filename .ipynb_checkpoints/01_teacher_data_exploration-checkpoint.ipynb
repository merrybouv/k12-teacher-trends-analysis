# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %%
import os

# List all files in your data folder
data_files = os.listdir('data')
print("Data files:")
for file in data_files:
    print(f"  {file}")
# Out:
# Data files:
#   staff_2015-16.xlsx
#   .DS_Store
#   staff_2014-15.txt
#   staff_2021-22.txt
#   staff_2023-24.txt
#   staff_2017-18.txt
#   staff_2019-20.txt
#   staff_2016-17.csv
#   staff_companion_2022-23.xlsx
#   staff_companion_2014-15.xlsx
#   staff_2018-19.txt
#   staff_2020-21.txt
#   staff_companion_2023-24.xlsx
#   staff_2022-23.txt

# %%
import os
import shutil

# Create a mapping of old names to new names
# decoding the years from the filenames
rename_map = {
    'ccd_sea_059_1415_w_0216161a.txt': 'staff_2014-15.txt',
    'ccd_sea_059_1516_w_1a_011717.xlsx': 'staff_2015-16.xlsx', 
    'ccd_sea_059_1617_l_1a_11212017.csv': 'staff_2016-17.csv',
    'ccd_sea_059_1718_l_1a_083118': 'staff_2017-18.txt',
    'ccd_sea_059_1819_l_1a_091019': 'staff_2018-19.txt',
    'ccd_sea_059_1920_l_1a_082120': 'staff_2019-20.txt',
    'ccd_sea_059_2021_l_1a_080621': 'staff_2020-21.txt',
    'ccd_sea_059_2122_l_1a_071722': 'staff_2021-22.txt',
    'ccd_sea_059_2223_l_1a_083023': 'staff_2022-23.txt',
    'ccd_sea_059_2324_l_1a_073124': 'staff_2023-24.txt'
}

# Rename the files
folder_path = 'data/STAFF data python GIT'
for old_name, new_name in rename_map.items():
    old_path = os.path.join(folder_path, old_name)
    new_path = os.path.join(folder_path, new_name)
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"Renamed: {old_name} → {new_name}")

# %%
import os

# Create a mapping of old names to new names
rename_map = {
    'ccd_sea_059_1415_w_0216161a.txt': 'staff_2014-15.txt',
    'ccd_sea_059_1516_w_1a_011717.xlsx': 'staff_2015-16.xlsx', 
    'ccd_sea_059_1617_l_1a_11212017.csv': 'staff_2016-17.csv',
    'ccd_sea_059_1718_l_1a_083118': 'staff_2017-18.txt',
    'ccd_sea_059_1819_l_1a_091019': 'staff_2018-19.txt',
    'ccd_sea_059_1920_l_1a_082120': 'staff_2019-20.txt',
    'ccd_sea_059_2021_l_1a_080621': 'staff_2020-21.txt',
    'ccd_sea_059_2122_l_1a_071722': 'staff_2021-22.txt',
    'ccd_sea_059_2223_l_1a_083023': 'staff_2022-23.txt',
    'ccd_sea_059_2324_l_1a_073124': 'staff_2023-24.txt'
}

# Rename the files in the data folder
for old_name, new_name in rename_map.items():
    old_path = os.path.join('data', old_name)
    new_path = os.path.join('data', new_name)
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"Renamed: {old_name} → {new_name}")
    else:
        print(f"File not found: {old_name}")
# Out:
# File not found: ccd_sea_059_1415_w_0216161a.txt
# File not found: ccd_sea_059_1516_w_1a_011717.xlsx
# File not found: ccd_sea_059_1617_l_1a_11212017.csv
# File not found: ccd_sea_059_1718_l_1a_083118
# File not found: ccd_sea_059_1819_l_1a_091019
# File not found: ccd_sea_059_1920_l_1a_082120
# File not found: ccd_sea_059_2021_l_1a_080621
# File not found: ccd_sea_059_2122_l_1a_071722
# File not found: ccd_sea_059_2223_l_1a_083023
# File not found: ccd_sea_059_2324_l_1a_073124

# %%
import os

# Create a mapping of old names to new names (including companion files)
rename_map = {
    # Staff data files
    'ccd_sea_059_1415_w_0216161a.txt': 'staff_2014-15.txt',
    'ccd_sea_059_1516_w_1a_011717.xlsx': 'staff_2015-16.xlsx', 
    'ccd_sea_059_1617_l_1a_11212017.csv': 'staff_2016-17.csv',
    'ccd_sea_059_1718_l_1a_083118': 'staff_2017-18.txt',
    'ccd_sea_059_1819_l_1a_091019': 'staff_2018-19.txt',
    'ccd_sea_059_1920_l_1a_082120': 'staff_2019-20.txt',
    'ccd_sea_059_2021_l_1a_080621': 'staff_2020-21.txt',
    'ccd_sea_059_2122_l_1a_071722': 'staff_2021-22.txt',
    'ccd_sea_059_2223_l_1a_083023': 'staff_2022-23.txt',
    'ccd_sea_059_2324_l_1a_073124': 'staff_2023-24.txt',
    
    # Companion files (documentation)
    '2014-15 CCD Companion_SEA Staff.xlsx': 'staff_companion_2014-15.xlsx',
    'SY_2022-23_SEA_Staff_Companion_2024-152.xlsx': 'staff_companion_2022-23.xlsx',
    'SY_2023-24_SEA_Staff_Companion_2024-252.xlsx': 'staff_companion_2023-24.xlsx'
}

# Rename the files in the data folder
for old_name, new_name in rename_map.items():
    old_path = os.path.join('data', old_name)
    new_path = os.path.join('data', new_name)
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"Renamed: {old_name} → {new_name}")
    else:
        print(f"File not found: {old_name}")
# Out:
# File not found: ccd_sea_059_1415_w_0216161a.txt
# File not found: ccd_sea_059_1516_w_1a_011717.xlsx
# File not found: ccd_sea_059_1617_l_1a_11212017.csv
# File not found: ccd_sea_059_1718_l_1a_083118
# File not found: ccd_sea_059_1819_l_1a_091019
# File not found: ccd_sea_059_1920_l_1a_082120
# File not found: ccd_sea_059_2021_l_1a_080621
# File not found: ccd_sea_059_2122_l_1a_071722
# File not found: ccd_sea_059_2223_l_1a_083023
# File not found: ccd_sea_059_2324_l_1a_073124
# File not found: 2014-15 CCD Companion_SEA Staff.xlsx
# File not found: SY_2022-23_SEA_Staff_Companion_2024-152.xlsx
# File not found: SY_2023-24_SEA_Staff_Companion_2024-252.xlsx

# %%
import os
# exploring the staff_2023-24.txt "folder"
files_inside = os.listdir('data/staff_2023-24.txt')
print("Files inside staff_2023-24.txt:")
for file in files_inside:
    print(f"  {file}")
# Out:
# Files inside staff_2023-24.txt:
#   ccd_sea_059_2324_l_1a_073124.sas7bdat
#   ccd_sea_059_2324_l_1a_073124.csv

# %%
df_2023 = pd.read_csv('data/staff_2023-24.txt/ccd_sea_059_2324_l_1a_073124.csv')
print("Shape of data:", df_2023.shape)
print("\nColumn names:")
print(df_2023.columns.tolist())
# Out:
# Shape of data: (1454, 10)
#
# Column names:
# ['SCHOOL_YEAR', 'FIPST', 'STATENAME', 'ST', 'SEA_NAME', 'STATE_AGENCY_NO', 'STAFF', 'STAFF_COUNT', 'TOTAL_INDICATOR', 'DMS_FLAG']

# %%
print("First 5 rows:")
df_2023.head()
# Out:
# First 5 rows:
#   SCHOOL_YEAR  FIPST STATENAME  ST                               SEA_NAME  \
# 0   2023-2024      1   ALABAMA  AL  Alabama State Department of Education
# 1   2023-2024      1   ALABAMA  AL  Alabama State Department of Education
# 2   2023-2024      1   ALABAMA  AL  Alabama State Department of Education
# 3   2023-2024      1   ALABAMA  AL  Alabama State Department of Education
# 4   2023-2024      1   ALABAMA  AL  Alabama State Department of Education
#
#    STATE_AGENCY_NO                                              STAFF  \
# 0                1                            All Other Support Staff
# 1                1                       Elementary School Counselors
# 2                1                                Elementary Teachers
# 3                1  Instructional Coordinators and Supervisors to ...
# 4                1                              Kindergarten Teachers
#
#    STAFF_COUNT TOTAL_INDICATOR  DMS_FLAG
# 0     13170.49  Category Set A  Reported
# ...

# %%
# See all the different types of staff
print("Types of staff in the data:")
print(df_2023['STAFF'].value_counts())
# Out:
# Types of staff in the data:
# STAFF
# All Other Support Staff                                    57
# Elementary School Counselors                               57
# Elementary Teachers                                        57
# Instructional Coordinators and Supervisors to the Staff    57
# Kindergarten Teachers                                      57
# LEA Administrative Support Staff                           57
# LEA Administrators                                         57
# Librarians/media specialists                               57
# Library/Media Support Staff                                57
# Missing                                                    57
# Paraprofessionals/Instructional Aides                      57
# Pre-kindergarten Teachers                                  57
# School Administrative Support Staff                        57
# School administrators                                      57
# School Counselors                                          57
# ...

# %%
# Define teacher categories
teacher_types = [
    'Elementary Teachers',
    'Secondary Teachers', 
    'Kindergarten Teachers',
    'Pre-kindergarten Teachers',
    'Ungraded Teachers',
    'Teachers'  # This might be a catch-all category
]

# Filter for just teachers
teachers_only = df_2023[df_2023['STAFF'].isin(teacher_types)]

print(f"Total rows with teachers: {len(teachers_only)}")
print(f"Teacher types found: {teachers_only['STAFF'].value_counts()}")
# Out:
# Total rows with teachers: 314
# Teacher types found: STAFF
# Elementary Teachers          57
# Kindergarten Teachers        57
# Pre-kindergarten Teachers    57
# Secondary Teachers           57
# Teachers                     57
# Ungraded Teachers            29
# Name: count, dtype: int64

# %%
# Look at teacher data by state
print("Teachers by state (first 10 states):")
teachers_by_state = teachers_only.groupby(['STATENAME', 'STAFF'])['STAFF_COUNT'].sum().reset_index()
print(teachers_by_state.head(10))
# Out:
# Teachers by state (first 10 states):
#   STATENAME                      STAFF  STAFF_COUNT
# 0   ALABAMA        Elementary Teachers     18395.46
# 1   ALABAMA      Kindergarten Teachers      2980.76
# 2   ALABAMA  Pre-kindergarten Teachers      1292.99
# 3   ALABAMA         Secondary Teachers     20188.71
# 4   ALABAMA                   Teachers     42857.92
# 5    ALASKA        Elementary Teachers      2985.09
# 6    ALASKA      Kindergarten Teachers       399.19
# 7    ALASKA  Pre-kindergarten Teachers       163.48
# 8    ALASKA         Secondary Teachers      3673.47
# 9    ALASKA                   Teachers      7221.23

# %%
# Total teachers by type across all states
print("Total teachers by type (across all states):")
total_by_type = teachers_only.groupby('STAFF')['STAFF_COUNT'].sum().sort_values(ascending=False)
print(total_by_type)

print("\n" + "="*50)

# Total teachers by state (all types combined)
print("Top 10 states by total teacher count:")
total_by_state = teachers_only.groupby('STATENAME')['STAFF_COUNT'].sum().sort_values(ascending=False)
print(total_by_state.head(10))
# Out:
# Total teachers by type (across all states):
# STAFF
# Teachers                     3283716.10
# Elementary Teachers          1546471.83
# Secondary Teachers           1300571.55
# Kindergarten Teachers         193184.09
# Ungraded Teachers             170012.09
# Pre-kindergarten Teachers      73476.54
# Name: STAFF_COUNT, dtype: float64
#
# ...
# Top 10 states by total teacher count:
# STATENAME
# TEXAS             753163.82
# CALIFORNIA        536389.26
# NEW YORK          435043.26
# FLORIDA           311599.30
# ILLINOIS          272984.40
# PENNSYLVANIA      259090.56
# GEORGIA           247280.20
# NEW JERSEY        236062.80
# NORTH CAROLINA    201988.26
# OHIO              201318.20
# Name: STAFF_COUNT, dtype: float64

# %%
# exploring 2019-20 data to compare trends
df_2019 = pd.read_csv('data/staff_2019-20.txt/ccd_sea_059_1920_l_1a_082120.csv')

# Filter for teachers
teachers_2019 = df_2019[df_2019['STAFF'].isin(teacher_types)]

# Compare total teachers: 2019 vs 2023
total_2019 = teachers_2019.groupby('STATENAME')['STAFF_COUNT'].sum()
total_2023 = teachers_only.groupby('STATENAME')['STAFF_COUNT'].sum()

# Calculate change
teacher_change = ((total_2023 - total_2019) / total_2019 * 100).round(2)
teacher_change = teacher_change.sort_values()

print("States with biggest teacher workforce changes (2019 to 2023):")
print("DECREASES:")
print(teacher_change.head(10))
print("\nINCREASES:")
print(teacher_change.tail(10))
# Out:
# States with biggest teacher workforce changes (2019 to 2023):
# DECREASES:
# STATENAME
# BUREAU OF INDIAN EDUCATION   -44.84
# GUAM                         -20.53
# NEVADA                       -11.66
# U.S. VIRGIN ISLANDS           -6.97
# FLORIDA                       -6.15
# OHIO                          -5.04
# ALASKA                        -3.51
# NEW HAMPSHIRE                 -1.36
# CALIFORNIA                    -1.33
# OKLAHOMA                      -1.30
# Name: STAFF_COUNT, dtype: float64
#
# INCREASES:
# STATENAME
# MINNESOTA                6.38
# MISSISSIPPI              6.70
# SOUTH CAROLINA           6.88
# VIRGINIA                 7.90
# INDIANA                  9.17
# UTAH                    10.84
# DISTRICT OF COLUMBIA    12.50
# LOUISIANA               26.63
# AMERICAN SAMOA            NaN
# NORTHERN MARIANAS         NaN
# Name: STAFF_COUNT, dtype: float64

# %%
# Check the 2023-24 companion file
companion_2023 = pd.read_excel('data/staff_companion_2023-24.xlsx')

print("2023-24 Companion file shape:", companion_2023.shape)
print("\nFirst few rows:")
print(companion_2023.head(10))
# Out:
# 2023-24 Companion file shape: (31, 5)
#
# First few rows:
#                 Product Title Final Common Core of Data - SEA Staffing  \
# 0                 School Year                                2023-2024
# 1                   Filenames             ccd_sea_059_2324_l_1a_073124
# 2                         NaN                                      NaN
# 3                  As-of date             All data as of July 31, 2024
# 4                         NaN                                      NaN
# 5          Publication number                            NCES 2024-252
# 6                         NaN                                      NaN
# 7  File variables and records                          Data file level
# 8                         NaN                                      SEA
# 9                         NaN                                      NaN
#
#             Unnamed: 2                 Unnamed: 3         Unnamed: 4
# ...

# %%
# Check if there are multiple sheets in the Excel file
xl_file = pd.ExcelFile('data/staff_companion_2023-24.xlsx')
print("Sheet names in 2023-24 companion:")
print(xl_file.sheet_names)
# Out:
# Sheet names in 2023-24 companion:
# ['Introduction', 'File Layout', 'Derived Variables', 'Stats-Char', 'Stats-Cat', 'Stats-Continuous']

# %%
# Check the "File Layout" sheet
layout = pd.read_excel('data/staff_companion_2023-24.xlsx', sheet_name='File Layout')
print("File Layout (column definitions):")
print(layout)
# Out:
# File Layout (column definitions):
#    New Field?    Variable Name  \
# 0         NaN      SCHOOL_YEAR
# 1         NaN            FIPST
# 2         NaN        STATENAME
# 3         NaN               ST
# 4         NaN         SEA_NAME
# 5         NaN  STATE_AGENCY_NO
# 6         NaN            STAFF
# 7         NaN      STAFF_COUNT
# 8         NaN  TOTAL_INDICATOR
# 9         NaN         DMS_FLAG
#
#                             Changes from prior years Variable Type  Length  \
# 0                                 Var name: SURVYEAR          Char       9
# 1                                                NaN          Char       2
# 2                                                NaN          Char      44
# 3                                    Var name: STABR          Char       2
# 4                                                NaN          Char      59
# 5                                    New for 2016-17          Char       3
# ...

# %%
# Check "Stats-Cat"
stats_cat = pd.read_excel('data/staff_companion_2023-24.xlsx', sheet_name='Stats-Cat')
print("\nStaff Categories explanation:")
print(stats_cat)
# Out:
# Staff Categories explanation:
#                   Variables, values, and value labels  Frequency    Percent  \
# 0                                               STAFF        NaN        NaN
# 1                             All Other Support Staff       57.0   3.920220
# 2                        Elementary School Counselors       57.0   3.920220
# 3                                 Elementary Teachers       57.0   3.920220
# 4                                 Guidance Counselors       57.0   3.920220
# 5   Instructional Coordinators and Supervisors to ...       57.0   3.920220
# 6                               Kindergarten Teachers       57.0   3.920220
# 7                    LEA Administrative Support Staff       57.0   3.920220
# 8                                  LEA Administrators       57.0   3.920220
# 9                                           LEA Staff       57.0   3.920220
# 10                       Librarians/media specialists       57.0   3.920220
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
# Check if the 2014-15 file has the same structure
xl_file_2014 = pd.ExcelFile('data/staff_companion_2014-15.xlsx')
print("Sheet names in 2014-15 companion:")
print(xl_file_2014.sheet_names)
# Out:
# Sheet names in 2014-15 companion:
# ['Introduction', 'File Layout', 'Statistics-Character Strings', 'Statistics-Categorical Variable', 'Statistics-Continuous Variables', 'State Notes', 'Guam Crosswalk', 'State Codes']

# %%
# Check the staff categories from 2014-15
stats_cat_2014 = pd.read_excel('data/staff_companion_2014-15.xlsx', sheet_name='Statistics-Categorical Variable')
print("2014-15 Staff Categories:")
print(stats_cat_2014.head(30))
# Out:
# 2014-15 Staff Categories:
#                   Variables, values, and value labels  Frequency  Percent  \
# 0                                             ISCHSUP        NaN      NaN
# 1                                        A-Adjustment        3.0     5.36
# 2             P-Imputation based on prior year's data        4.0     7.14
# 3                          R-As reported by the state       49.0    87.50
# 4                                                 NaN        NaN      NaN
# 5                                             ISECTCH        NaN      NaN
# 6                                        A-Adjustment        2.0     3.57
# 7             P-Imputation based on prior year's data        3.0     5.36
# 8                          R-As reported by the state       51.0    91.07
# 9                                                 NaN        NaN      NaN
# 10                                             ISTAFF        NaN      NaN
# ...

# %%
# figuring out 2014-15 file
for sheet_name in xl_file_2014.sheet_names:
    try:
        sheet_data = pd.read_excel('data/staff_companion_2014-15.xlsx', sheet_name=sheet_name)
        print(f"\n--- {sheet_name} ---")
        print(f"Shape: {sheet_data.shape}")
        print("First few rows:")
        print(sheet_data.head(3))
        print("="*50)
    except Exception as e:
        print(f"Error reading {sheet_name}: {e}")
# Out:
# --- Introduction ---
# Shape: (30, 2)
# First few rows:
#         Product Title Common Core of Data SEA Staff
# 0         School Year                       2014-15
# 1            Filename   ccd_sea_059_1415_w_0216161a
# 2  Publication number            NCES 2016-077state
# ...
#
# --- File Layout ---
# Shape: (47, 13)
# First few rows:
#    Position New Field Flag Variable Name Prior Year Name Variable Type  \
# 0         1            NaN      SURVYEAR             NaN          Char
# 1         2            NaN         FIPST             NaN          Char
# 2         3            NaN         STABR             NaN          Char
#
#    Length                                        Description  \
# 0       9                Year corresponding to survey record
# 1       2  American National Standards Institute (ANSI) s...
# 2       2                     Postal state abbreviation code
#
#   Change to Categorical Values Flag           Categorical Values  \
# ...

# %%
# Load the 2014-15 data to see the actual column names
df_2014 = pd.read_csv('data/staff_2014-15.txt')
print("2014-15 columns:")
print(df_2014.columns.tolist())
print("\nFirst few rows:")
print(df_2014.head())
# Out:
# 2014-15 columns:
# ['SURVYEAR\tFIPST\tSTABR\tSTATENAME\tSEANAME\tSCHSUP\tSECTCH\tSTAFF\tELMGUI\tKGTCH\tLEASUP\tPARA\tSECGUI\tCORSUP\tELMTCH\tLIBSUP\tSCHADM\tSTUSUP\tGUI\tLEAADM\tLIBSPE\tOTHSUP\tPKTCH\tUGTCH\tTOTTCH\tTOTGUI\tISCHSUP\tISECTCH\tISTAFF\tIELMGUI\tIKGTCH\tILEASUP\tIPARA\tISECGUI\tICORSUP\tIELMTCH\tILIBSUP\tISCHADM\tISTUSUP\tIGUI\tILEAADM\tILIBSPE\tIOTHSUP\tIPKTCH\tIUGTCH\tITOTTCH\tITOTGUI']
#
# First few rows:
#   SURVYEAR\tFIPST\tSTABR\tSTATENAME\tSEANAME\tSCHSUP\tSECTCH\tSTAFF\tELMGUI\tKGTCH\tLEASUP\tPARA\tSECGUI\tCORSUP\tELMTCH\tLIBSUP\tSCHADM\tSTUSUP\tGUI\tLEAADM\tLIBSPE\tOTHSUP\tPKTCH\tUGTCH\tTOTTCH\tTOTGUI\tISCHSUP\tISECTCH\tISTAFF\tIELMGUI\tIKGTCH\tILEASUP\tIPARA\tISECGUI\tICORSUP\tIELMTCH\tILIBSUP\tISCHADM\tISTUSUP\tIGUI\tILEAADM\tILIBSPE\tIOTHSUP\tIPKTCH\tIUGTCH\tITOTTCH\tITOTGUI
# 0  2014-2015\t01\tAL\tALABAMA\tAlabama Department...
# 1  2014-2015\t02\tAK\tALASKA\tAlaska Department o...
# 2  2014-2015\t04\tAZ\tARIZONA\tArizona Department...
# ...

# %%
# Load the 2014-15 data with proper tab delimiter
df_2014 = pd.read_csv('data/staff_2014-15.txt', sep='\t')
print("2014-15 columns (properly parsed):")
print(df_2014.columns.tolist())
print("\nFirst few rows:")
print(df_2014.head())
# Out:
# 2014-15 columns (properly parsed):
# ['SURVYEAR', 'FIPST', 'STABR', 'STATENAME', 'SEANAME', 'SCHSUP', 'SECTCH', 'STAFF', 'ELMGUI', 'KGTCH', 'LEASUP', 'PARA', 'SECGUI', 'CORSUP', 'ELMTCH', 'LIBSUP', 'SCHADM', 'STUSUP', 'GUI', 'LEAADM', 'LIBSPE', 'OTHSUP', 'PKTCH', 'UGTCH', 'TOTTCH', 'TOTGUI', 'ISCHSUP', 'ISECTCH', 'ISTAFF', 'IELMGUI', 'IKGTCH', 'ILEASUP', 'IPARA', 'ISECGUI', 'ICORSUP', 'IELMTCH', 'ILIBSUP', 'ISCHADM', 'ISTUSUP', 'IGUI', 'ILEAADM', 'ILIBSPE', 'IOTHSUP', 'IPKTCH', 'IUGTCH', 'ITOTTCH', 'ITOTGUI']
#
# First few rows:
#     SURVYEAR  FIPST STABR   STATENAME  \
# 0  2014-2015      1    AL     ALABAMA
# 1  2014-2015      2    AK      ALASKA
# 2  2014-2015      4    AZ     ARIZONA
# 3  2014-2015      5    AR    ARKANSAS
# 4  2014-2015      6    CA  CALIFORNIA
#
#                                              SEANAME    SCHSUP    SECTCH  \
# 0                    Alabama Department Of Education   2593.71  20076.30
# ...

# %%
# Exploring teacher data for 2014-15
teacher_columns_2014 = ['ELMTCH', 'SECTCH', 'KGTCH', 'PKTCH', 'UGTCH', 'TOTTCH']

print("2014-15 Teacher data by state:")
print(df_2014[['STATENAME'] + teacher_columns_2014].head(10))
# Out:
# 2014-15 Teacher data by state:
#               STATENAME     ELMTCH    SECTCH     KGTCH    PKTCH     UGTCH  \
# 0               ALABAMA   17240.17  20076.30   4760.82   659.50     -2.00
# 1                ALASKA    3662.21   3501.81    449.12   145.94     -2.00
# 2               ARIZONA   30258.11  14850.94   2676.72   338.71     -2.00
# 3              ARKANSAS   15690.74  14287.98   2247.16   613.17   2590.99
# 4            CALIFORNIA  153218.00  85079.36  22160.54  4715.00   2512.13
# 5              COLORADO   24613.52  21900.11   3833.32  1041.10     -2.00
# 6           CONNECTICUT   23757.03  15237.28   1959.15   877.89    230.59
# 7              DELAWARE    4348.75   4770.00    442.00    88.00     -2.00
# 8  DISTRICT OF COLUMBIA    3414.57   1721.50    445.49   946.18     37.56
# 9               FLORIDA   64379.15  66300.52  10004.02  2669.28  37089.30
#
#       TOTTCH
# 0   42736.79
# 1    7759.08
# 2   48124.48
# 3   35430.04
# 4  267685.03
# 5   51388.05
# 6   42061.94
# ...

# %%
# Check if total teachers equals sum of individual categories in 2014-15
# Replace -2 with 0 for calculation (missing data)
df_2014_calc = df_2014.copy()
teacher_components = ['ELMTCH', 'SECTCH', 'KGTCH', 'PKTCH', 'UGTCH']

# Replace -2 (missing codes) with 0 for calculation
for col in teacher_components:
    df_2014_calc[col] = df_2014_calc[col].replace(-2, 0)

# Calculate sum and compare to reported total
df_2014_calc['CALCULATED_TOTAL'] = df_2014_calc[teacher_components].sum(axis=1)
df_2014_calc['DIFFERENCE'] = df_2014_calc['TOTTCH'] - df_2014_calc['CALCULATED_TOTAL']

print("Checking data consistency (first 10 states):")
print(df_2014_calc[['STATENAME', 'TOTTCH', 'CALCULATED_TOTAL', 'DIFFERENCE']].head(10))
# Out:
# Checking data consistency (first 10 states):
#               STATENAME     TOTTCH  CALCULATED_TOTAL    DIFFERENCE
# 0               ALABAMA   42736.79          42736.79  0.000000e+00
# 1                ALASKA    7759.08           7759.08  0.000000e+00
# 2               ARIZONA   48124.48          48124.48  0.000000e+00
# 3              ARKANSAS   35430.04          35430.04  0.000000e+00
# 4            CALIFORNIA  267685.03         267685.03  0.000000e+00
# 5              COLORADO   51388.05          51388.05  0.000000e+00
# 6           CONNECTICUT   42061.94          42061.94  7.275958e-12
# 7              DELAWARE    9648.75           9648.75  0.000000e+00
# 8  DISTRICT OF COLUMBIA    6565.30           6565.30  0.000000e+00
# 9               FLORIDA  180442.27         180442.27 -2.910383e-11

# %%
# Check when the data format changed from wide to long
import os

# All staff data files
data_files = [f for f in os.listdir('data') if f.startswith('staff_') and not f.endswith('.xlsx')]
data_files.sort()  # Sort by year

print("Checking data format across all years:")
print("="*50)

for file in data_files:
   try:
       # Try to load each file and check its structure
       if file.endswith('.txt'):
           # Check if it's a folder (like newer years) or actual file
           file_path = f'data/{file}'
           if os.path.isdir(file_path):
               # It's a folder, look for CSV inside
               csv_files = [f for f in os.listdir(file_path) if f.endswith('.csv')]
               if csv_files:
                   df = pd.read_csv(f'{file_path}/{csv_files[0]}')
               else:
                   print(f"{file}: No CSV found in folder")
                   continue
           else:
               # It's an actual text file, try tab-delimited first
               df = pd.read_csv(file_path, sep='\t')
       else:
           # Handle other formats
           df = pd.read_csv(f'data/{file}')
       
       # Check format type
       if 'STAFF' in df.columns and len(df.columns) < 20:
           format_type = "LONG (new format)"
       elif 'ELMTCH' in df.columns or 'SECTCH' in df.columns:
           format_type = "WIDE (old format)"
       else:
           format_type = "UNKNOWN"
       
       print(f"{file}: {format_type} - {len(df.columns)} columns")
       
   except Exception as e:
       print(f"{file}: ERROR - {str(e)[:50]}...")

print("\n" + "="*50)
# Out:
# Checking data format across all years:
# ...
# staff_2014-15.txt: WIDE (old format) - 47 columns
# staff_2016-17.csv: LONG (new format) - 10 columns
# staff_2017-18.txt: LONG (new format) - 10 columns
# staff_2018-19.txt: LONG (new format) - 10 columns
# staff_2019-20.txt: LONG (new format) - 10 columns
# staff_2020-21.txt: LONG (new format) - 10 columns
# staff_2021-22.txt: LONG (new format) - 10 columns
# staff_2022-23.txt: LONG (new format) - 10 columns
# staff_2023-24.txt: LONG (new format) - 10 columns
#
# ...

# %%
# Multi-Year NCES Staff Data Loading and Consolidation
import pandas as pd
import os

# Load 8 years of consistent format data (2016-2024)
file_list = [
    'staff_2016-17.csv',
    'staff_2017-18.txt', 
    'staff_2018-19.txt',
    'staff_2019-20.txt',
    'staff_2020-21.txt',
    'staff_2021-22.txt',
    'staff_2022-23.txt',
    'staff_2023-24.txt'
]

print(f"Loading {len(file_list)} years of NCES staff data")

# Store dataframes for concatenation
all_dataframes = []

# Process each data file
for filename in file_list:
    try:
        file_path = f'data/{filename}'
        
        # Handle both folder and file structures in NCES data
        if os.path.isdir(file_path):
            csv_files = [f for f in os.listdir(file_path) if f.endswith('.csv')]
            if csv_files:
                df = pd.read_csv(f'{file_path}/{csv_files[0]}')
            else:
                print(f"No CSV found in {filename}")
                continue
        else:
            if filename.endswith('.csv'):
                df = pd.read_csv(file_path)
            else:
                df = pd.read_csv(file_path, sep='\t')
        
        # Extract academic year from filename
        year = filename.replace('staff_', '').replace('.txt', '').replace('.csv', '')
        df['YEAR'] = year
        
        all_dataframes.append(df)
        print(f"Loaded {len(df):,} records for {year}")
        
    except Exception as e:
        print(f"Error loading {filename}: {str(e)}")

# Combine all years into single dataset
if all_dataframes:
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    
    print(f"\nDataset Summary:")
    print(f"Total records: {len(combined_df):,}")
    print(f"Years: {sorted(combined_df['YEAR'].unique())}")
    print(f"Jurisdictions: {len(combined_df['STATENAME'].unique())}")
    print(f"Staff categories: {len(combined_df['STAFF'].unique())}")
    
    # Data quality check
    missing_counts = combined_df.isnull().sum()
    print(f"\nMissing values:")
    for col, count in missing_counts.items():
        if count > 0:
            print(f"  {col}: {count:,}")
    
    # Year coverage
    print(f"\nRecords per year:")
    year_counts = combined_df['YEAR'].value_counts().sort_index()
    for year, count in year_counts.items():
        print(f"  {year}: {count:,}")
        
    print(f"\nFirst few records:")
    print(combined_df.head())
    
else:
    print("No data files loaded successfully")
# Out:
# Loading 8 years of NCES staff data
# Loaded 1,405 records for 2016-17
# Loaded 1,379 records for 2017-18
# Loaded 1,382 records for 2018-19
# Loaded 1,436 records for 2019-20
# Loaded 1,434 records for 2020-21
# Loaded 1,460 records for 2021-22
# Loaded 1,457 records for 2022-23
# Loaded 1,454 records for 2023-24
#
# Dataset Summary:
# Total records: 11,407
# Years: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
# Jurisdictions: 58
# Staff categories: 27
#
# Missing values:
#   STAFF_COUNT: 848
#
# Records per year:
#   2016-17: 1,405
#   2017-18: 1,379
#   2018-19: 1,382
#   2019-20: 1,436
#   2020-21: 1,434
#   2021-22: 1,460
#   2022-23: 1,457
#   2023-24: 1,454
#
# First few records:
#   SCHOOL_YEAR  FIPST STATENAME  ST                         SEA_NAME  \
# 0   2016-2017      1   ALABAMA  AL  Alabama Department Of Education
# 1   2016-2017      1   ALABAMA  AL  Alabama Department Of Education
# ...

# %%
# Multi-Year NCES Staff Data Loading and Consolidation
import pandas as pd
import os

# Load 8 years of consistent format data (2016-2024)
file_list = [
    'staff_2016-17.csv',
    'staff_2017-18.txt', 
    'staff_2018-19.txt',
    'staff_2019-20.txt',
    'staff_2020-21.txt',
    'staff_2021-22.txt',
    'staff_2022-23.txt',
    'staff_2023-24.txt'
]

print(f"Loading {len(file_list)} years of NCES staff data")

# Store dataframes for concatenation
all_dataframes = []

# Process each data file
for filename in file_list:
    try:
        file_path = f'data/{filename}'
        
        # Handle both folder and file structures in NCES data
        if os.path.isdir(file_path):
            csv_files = [f for f in os.listdir(file_path) if f.endswith('.csv')]
            if csv_files:
                df = pd.read_csv(f'{file_path}/{csv_files[0]}')
            else:
                print(f"No CSV found in {filename}")
                continue
        else:
            if filename.endswith('.csv'):
                df = pd.read_csv(file_path)
            else:
                df = pd.read_csv(file_path, sep='\t')
        
        # Extract academic year from filename
        year = filename.replace('staff_', '').replace('.txt', '').replace('.csv', '')
        df['YEAR'] = year
        
        all_dataframes.append(df)
        print(f"Loaded {len(df):,} records for {year}")
        
    except Exception as e:
        print(f"Error loading {filename}: {str(e)}")

# Combine all years into single dataset
if all_dataframes:
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    
    print(f"\nCombined Dataset Summary:")
    print(f"Total records: {len(combined_df):,}")
    print(f"Years covered: {sorted(combined_df['YEAR'].unique())}")
    print(f"States/jurisdictions: {len(combined_df['STATENAME'].unique())}")
    print(f"Staff categories: {len(combined_df['STAFF'].unique())}")
    
    # Data quality assessment
    missing_counts = combined_df.isnull().sum()
    print(f"\nData Quality Check:")
    print("Missing values by column:")
    for col, count in missing_counts.items():
        if count > 0:
            pct_missing = (count / len(combined_df)) * 100
            print(f"  {col}: {count:,} missing ({pct_missing:.1f}%)")
    
    # Year-by-year coverage analysis
    print(f"\nYear Coverage Analysis:")
    year_counts = combined_df['YEAR'].value_counts().sort_index()
    for year, count in year_counts.items():
        print(f"  {year}: {count:,} records")
    
    # Check for data consistency patterns
    min_records = year_counts.min()
    max_records = year_counts.max()
    variation = max_records - min_records
    print(f"\nRecord count variation: {variation:,} records ({min_records:,} to {max_records:,})")
    print("This variation is normal for government education data due to:")
    print("- States not reporting all staff categories each year")
    print("- Changes in data collection requirements")
    print("- Jurisdictional differences in staff organization")
        
    print(f"\nSample records:")
    print(combined_df.head())
    
else:
    print("No data files loaded successfully")
# Out:
# Loading 8 years of NCES staff data
# Loaded 1,405 records for 2016-17
# Loaded 1,379 records for 2017-18
# Loaded 1,382 records for 2018-19
# Loaded 1,436 records for 2019-20
# Loaded 1,434 records for 2020-21
# Loaded 1,460 records for 2021-22
# Loaded 1,457 records for 2022-23
# Loaded 1,454 records for 2023-24
#
# Combined Dataset Summary:
# Total records: 11,407
# Years covered: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
# States/jurisdictions: 58
# Staff categories: 27
#
# Data Quality Check:
# Missing values by column:
#   STAFF_COUNT: 848 missing (7.4%)
#
# Year Coverage Analysis:
#   2016-17: 1,405 records
#   2017-18: 1,379 records
#   2018-19: 1,382 records
#   2019-20: 1,436 records
#   2020-21: 1,434 records
#   2021-22: 1,460 records
#   2022-23: 1,457 records
#   2023-24: 1,454 records
#
# Record count variation: 81 records (1,379 to 1,460)
# This variation is normal for government education data due to:
# ...

# %%
# Teacher Workforce Trends Analysis (2016-2024)
# Analysis of national and state-level patterns in teacher employment

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Filter to main "Teachers" category for consistency across years
teachers_df = combined_df[combined_df['STAFF'] == 'Teachers'].copy()

print("Teacher Workforce Analysis")
print("=" * 50)
print(f"Records analyzed: {len(teachers_df):,}")
print(f"Years covered: {sorted(teachers_df['YEAR'].unique())}")
print(f"Jurisdictions: {len(teachers_df['STATENAME'].unique())}")

# Remove records with missing teacher counts
teachers_clean = teachers_df.dropna(subset=['STAFF_COUNT'])
missing_count = len(teachers_df) - len(teachers_clean)
if missing_count > 0:
    print(f"Records with missing teacher counts excluded: {missing_count}")

# National teacher workforce trends
print(f"\nNational Teacher Workforce Trends")
print("-" * 40)

national_totals = teachers_clean.groupby('YEAR')['STAFF_COUNT'].sum().sort_index()

print("Annual teacher totals:")
for year, total in national_totals.items():
    print(f"  {year}: {total:,.0f}")

# Calculate year-over-year changes
print(f"\nYear-over-year changes:")
for i in range(1, len(national_totals)):
    current_year = national_totals.index[i]
    previous_year = national_totals.index[i-1]
    current_total = national_totals.iloc[i]
    previous_total = national_totals.iloc[i-1]
    
    change = current_total - previous_total
    pct_change = (change / previous_total) * 100
    
    direction = "increase" if change > 0 else "decrease"
    print(f"  {previous_year} to {current_year}: {abs(change):,.0f} {direction} ({pct_change:+.1f}%)")

# State-level analysis: Compare first and last years
print(f"\nState-Level Changes (2016-17 to 2023-24)")
print("-" * 45)

# Get data for comparison years
first_year = teachers_clean[teachers_clean['YEAR'] == '2016-17'].set_index('STATENAME')['STAFF_COUNT']
last_year = teachers_clean[teachers_clean['YEAR'] == '2023-24'].set_index('STATENAME')['STAFF_COUNT']

# Calculate changes for states with both years of data
common_states = first_year.index.intersection(last_year.index)
state_changes = pd.DataFrame({
    'Teachers_2016': first_year[common_states],
    'Teachers_2023': last_year[common_states]
}).dropna()

state_changes['Change_Absolute'] = state_changes['Teachers_2023'] - state_changes['Teachers_2016']
state_changes['Change_Percent'] = (state_changes['Change_Absolute'] / state_changes['Teachers_2016']) * 100

# Sort by percentage change
state_changes_sorted = state_changes.sort_values('Change_Percent')

print("States with largest decreases:")
print(state_changes_sorted.head(8)[['Teachers_2016', 'Teachers_2023', 'Change_Absolute', 'Change_Percent']].round(1))

print(f"\nStates with largest increases:")
print(state_changes_sorted.tail(8)[['Teachers_2016', 'Teachers_2023', 'Change_Absolute', 'Change_Percent']].round(1))

# COVID impact analysis
print(f"\nCOVID-19 Impact Analysis")
print("-" * 30)

covid_before = teachers_clean[teachers_clean['YEAR'] == '2019-20'].set_index('STATENAME')['STAFF_COUNT']
covid_after = teachers_clean[teachers_clean['YEAR'] == '2020-21'].set_index('STATENAME')['STAFF_COUNT']

covid_impact = pd.DataFrame({
    'Pre_COVID': covid_before,
    'During_COVID': covid_after
}).dropna()

covid_impact['Change'] = covid_impact['During_COVID'] - covid_impact['Pre_COVID']
covid_impact['Percent_Change'] = (covid_impact['Change'] / covid_impact['Pre_COVID']) * 100

national_covid_change = covid_impact['Change'].sum()
national_covid_pct = (national_covid_change / covid_impact['Pre_COVID'].sum()) * 100

print(f"National COVID impact: {national_covid_change:,.0f} teachers ({national_covid_pct:.1f}%)")
print(f"States with largest COVID losses:")
covid_worst = covid_impact.sort_values('Percent_Change').head(5)
for state, row in covid_worst.iterrows():
    print(f"  {state}: {row['Percent_Change']:+.1f}% ({row['Change']:+,.0f})")

# Create comprehensive visualization
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# Plot 1: National trend
years_numeric = range(len(national_totals))
ax1.plot(years_numeric, national_totals.values, marker='o', linewidth=3, markersize=8, color='#2E86C1')
ax1.set_title('National Teacher Workforce Trend (2016-2024)', fontsize=14, fontweight='bold')
ax1.set_xlabel('Academic Year')
ax1.set_ylabel('Total Teachers (millions)')
ax1.set_xticks(years_numeric)
ax1.set_xticklabels(national_totals.index, rotation=45, ha='right')
ax1.grid(True, alpha=0.3)
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x/1e6:.1f}M'))

# Highlight COVID period
covid_start = list(national_totals.index).index('2019-20')
covid_end = list(national_totals.index).index('2020-21')
ax1.axvspan(covid_start, covid_end, alpha=0.2, color='red', label='COVID Impact')
ax1.legend()

# Plot 2: Top states by teacher count (2023-24)
top_states = teachers_clean[teachers_clean['YEAR'] == '2023-24'].nlargest(10, 'STAFF_COUNT')
ax2.barh(range(len(top_states)), top_states['STAFF_COUNT'] / 1000, color='#28B463')
ax2.set_title('Top 10 States by Teacher Count (2023-24)', fontsize=14, fontweight='bold')
ax2.set_xlabel('Teachers (thousands)')
ax2.set_yticks(range(len(top_states)))
ax2.set_yticklabels(top_states['STATENAME'], fontsize=10)
ax2.invert_yaxis()

# Plot 3: State-level changes (extreme cases)
state_changes_filtered = state_changes_sorted[state_changes_sorted.index != 'BUREAU OF INDIAN EDUCATION']
extreme_states = pd.concat([state_changes_filtered.head(6), state_changes_filtered.tail(6)])
colors = ['#E74C3C' if x < 0 else '#27AE60' for x in extreme_states['Change_Percent']]
bars = ax3.barh(range(len(extreme_states)), extreme_states['Change_Percent'], color=colors, alpha=0.8)
ax3.set_title('State Teacher Workforce Changes\n(2016-17 to 2023-24)', fontsize=14, fontweight='bold')
ax3.set_xlabel('Percent Change (%)')
ax3.set_yticks(range(len(extreme_states)))
ax3.set_yticklabels(extreme_states.index, fontsize=9)
ax3.axvline(x=0, color='black', linestyle='-', alpha=0.5)

# Plot 4: COVID impact distribution
ax4.hist(covid_impact['Percent_Change'], bins=15, alpha=0.7, color='#F39C12', edgecolor='black', linewidth=1)
ax4.set_title('Distribution of COVID Impact\n(2019-20 to 2020-21)', fontsize=14, fontweight='bold')
ax4.set_xlabel('Percent Change (%)')
ax4.set_ylabel('Number of States')
median_impact = covid_impact['Percent_Change'].median()
ax4.axvline(x=median_impact, color='red', linestyle='--', linewidth=2, 
           label=f'Median: {median_impact:.1f}%')
ax4.legend()

plt.tight_layout()
plt.show()

# Fixing graph for linkedin
fig_linkedin, ax = plt.subplots(1, 1, figsize=(10, 6))

years_numeric = range(len(national_totals))
ax.plot(years_numeric, national_totals.values, marker='o', linewidth=3, markersize=8, color='#2E86C1')
ax.set_title('National Teacher Workforce Trend (2016-2024)', fontsize=16, fontweight='bold')
ax.set_xlabel('Academic Year', fontsize=12)
ax.set_ylabel('Total Teachers (millions)', fontsize=12)
ax.set_xticks(years_numeric)
ax.set_xticklabels(national_totals.index, rotation=45, ha='right')
ax.grid(True, alpha=0.3)

covid_start = list(national_totals.index).index('2019-20')
covid_end = list(national_totals.index).index('2020-21')
ax.axvspan(covid_start, covid_end, alpha=0.2, color='red', label='COVID Impact')
ax.legend()

plt.tight_layout()
plt.savefig('outputs/national_teacher_trend_linkedin.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()


# Create standalone state changes chart
fig_states, ax = plt.subplots(1, 1, figsize=(10, 8))

state_changes_filtered = state_changes_sorted[state_changes_sorted.index != 'BUREAU OF INDIAN EDUCATION']
extreme_states = pd.concat([state_changes_filtered.head(6), state_changes_filtered.tail(6)])
colors = ['#E74C3C' if x < 0 else '#27AE60' for x in extreme_states['Change_Percent']]
bars = ax.barh(range(len(extreme_states)), extreme_states['Change_Percent'], color=colors, alpha=0.8)
ax.set_title('State Teacher Workforce Changes (2016-17 to 2023-24)', fontsize=16, fontweight='bold')
ax.set_xlabel('Percent Change (%)', fontsize=12)
ax.set_yticks(range(len(extreme_states)))
ax.set_yticklabels(extreme_states.index, fontsize=10)
ax.axvline(x=0, color='black', linestyle='-', alpha=0.5)

plt.tight_layout()
plt.savefig('outputs/state_teacher_workforce_changes.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()

# Summary findings
print(f"\nKey Findings Summary")
print("=" * 25)
print(f"• COVID Impact: {abs(national_covid_change):,.0f} teacher reduction in 2020-21 ({national_covid_pct:.1f}%)")
print(f"• Recovery: Teacher workforce has recovered to {national_totals.iloc[-1]:,.0f} by 2023-24")
print(f"• Regional Variation: State changes range from {state_changes_sorted['Change_Percent'].min():.1f}% to {state_changes_sorted['Change_Percent'].max():.1f}%")
print(f"• Largest Challenge: Florida lost {abs(state_changes_sorted.iloc[0]['Change_Absolute']):,.0f} teachers")
print(f"• Success Story: Utah gained {state_changes_sorted.iloc[-1]['Change_Absolute']:,.0f} teachers")
# Out:
# Teacher Workforce Analysis
# ...
# Records analyzed: 452
# Years covered: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
# Jurisdictions: 58
# Records with missing teacher counts excluded: 8
#
# National Teacher Workforce Trends
# ----------------------------------------
# Annual teacher totals:
#   2016-17: 3,201,841
#   2017-18: 3,201,057
#   2018-19: 3,203,954
#   2019-20: 3,231,368
#   2020-21: 3,062,348
#   2021-22: 3,217,867
#   2022-23: 3,253,432
#   2023-24: 3,283,716
#
# Year-over-year changes:
#   2016-17 to 2017-18: 784 decrease (-0.0%)
#   2017-18 to 2018-19: 2,897 increase (+0.1%)
#   2018-19 to 2019-20: 27,413 increase (+0.9%)
#   2019-20 to 2020-21: 169,019 decrease (-5.2%)
#   2020-21 to 2021-22: 155,518 increase (+5.1%)
#   2021-22 to 2022-23: 35,565 increase (+1.1%)
#   2022-23 to 2023-24: 30,284 increase (+0.9%)
#
# State-Level Changes (2016-17 to 2023-24)
# ---------------------------------------------
# ...

# %%
# Investigating Bureau of Indian Education Data Anomaly
# The infinity percent change in BIE teacher counts warrants investigation

# Examine BIE teacher reporting patterns
bie_data = teachers_df[teachers_df['STATENAME'] == 'BUREAU OF INDIAN EDUCATION'].copy()

print("Bureau of Indian Education Teacher Data Analysis")
print("=" * 55)

# Annual teacher counts
if len(bie_data) > 0:
    print("Teacher counts by year:")
    bie_by_year = bie_data.set_index('YEAR')['STAFF_COUNT'].sort_index()
    for year, count in bie_by_year.items():
        if pd.isna(count):
            print(f"  {year}: No data reported")
        else:
            print(f"  {year}: {count:,.1f} teachers")
    
    # Examine broader BIE staffing data
    print(f"\nBIE staff categories reported:")
    bie_all_staff = combined_df[combined_df['STATENAME'] == 'BUREAU OF INDIAN EDUCATION']
    bie_staff_types = bie_all_staff['STAFF'].unique()
    print(f"Total categories: {len(bie_staff_types)}")
    
    # Check elementary and secondary teacher breakdowns
    elementary_bie = bie_all_staff[bie_all_staff['STAFF'] == 'Elementary Teachers']
    secondary_bie = bie_all_staff[bie_all_staff['STAFF'] == 'Secondary Teachers']
    
    if len(elementary_bie) > 0 or len(secondary_bie) > 0:
        print(f"\nDetailed teacher categories:")
        
        if len(elementary_bie) > 0:
            print("Elementary Teachers by year:")
            for _, row in elementary_bie.iterrows():
                count = row['STAFF_COUNT']
                if pd.isna(count):
                    print(f"  {row['YEAR']}: No data")
                else:
                    print(f"  {row['YEAR']}: {count:,.1f}")
        
        if len(secondary_bie) > 0:
            print("Secondary Teachers by year:")
            for _, row in secondary_bie.iterrows():
                count = row['STAFF_COUNT']
                if pd.isna(count):
                    print(f"  {row['YEAR']}: No data")
                else:
                    print(f"  {row['YEAR']}: {count:,.1f}")

else:
    print("No BIE teacher data found.")

# Analysis and hypothesis
print(f"\nData Pattern Analysis:")
print("The BIE shows zero teachers in 2016-17 and 2017-18, then substantial")print("Calculating actual COVID impact percentage:")

# Using only the 53 states with consistent reporting
covid_pct_consistent = (covid_impact['Change'].sum() / covid_impact['Pre_COVID'].sum()) * 100
print(f"COVID impact from consistent reporting states: {covid_pct_consistent:.1f}%")

# The misleading calculation (including missing states)
apparent_drop_pct = ((national_totals['2020-21'] - national_totals['2019-20']) / national_totals['2019-20']) * 100
print(f"Apparent drop (including missing state data): {apparent_drop_pct:.1f}%")
print("numbers starting in 2018-19 (5,585), followed by a decline to 2,903 by 2023-24.")

print(f"\nPossible explanations:")
print("1. Reporting methodology change: BIE began separate data collection in 2018-19")
print("2. Administrative reclassification: Teachers moved between BIE and state systems")
print("3. Actual workforce changes: Combination of hiring surge followed by departures")
print("4. Data collection improvements: Enhanced federal education data systems")

print(f"\nNote on Bureau of Indian Education:")
print("The BIE operates approximately 183 schools serving Native American students")
print("on or near reservations. These include elementary, secondary, and residential")
print("schools under federal jurisdiction, distinct from state education systems.")

print(f"\nConclusion:")
print("The dramatic pattern in BIE data requires additional investigation with")
print("supplementary sources to distinguish between reporting changes and actual")
print("workforce trends in Native American education.")
# Out:
# Bureau of Indian Education Teacher Data Analysis
# ...
# Teacher counts by year:
#   2016-17: 0.0 teachers
#   2017-18: 0.0 teachers
#   2018-19: 5,585.0 teachers
#   2019-20: 5,263.0 teachers
#   2020-21: 4,026.0 teachers
#   2021-22: 4,637.7 teachers
#   2022-23: 2,947.6 teachers
#   2023-24: 2,903.2 teachers
#
# BIE staff categories reported:
# Total categories: 27
#
# Detailed teacher categories:
# Elementary Teachers by year:
#   2016-17: No data
#   2017-18: No data
#   2018-19: 1,630.0
#   2019-20: 3,750.0
#   2020-21: 2,971.0
#   2021-22: 3,170.8
#   2022-23: 1,979.2
#   2023-24: 1,879.6
# Secondary Teachers by year:
#   2016-17: No data
#   2017-18: No data
#   2018-19: 932.0
#   2019-20: 1,205.0
#   2020-21: 792.0
#   2021-22: 1,027.8
#   2022-23: 458.1
#   2023-24: 847.5
#
# Data Pattern Analysis:
# The BIE shows zero teachers in 2016-17 and 2017-18, then substantial
# numbers starting in 2018-19 (5,585), followed by a decline to 2,903 by 2023-24.
#
# Possible explanations:
# ...

# %%
print(f"Actual range: {state_changes_filtered['Change_Percent'].min():.1f}% to {state_changes_filtered['Change_Percent'].max():.1f}%")
# Out:
# Actual range: -26.4% to 23.9%

# %%
print(f"National COVID impact: {abs(national_covid_change):,.0f} teachers")
# Out:
# National COVID impact: 5,949 teachers

# %%
print("Checking the actual numbers:")
print(f"2019-20: {national_totals['2019-20']:,.0f}")
print(f"2020-21: {national_totals['2020-21']:,.0f}")
print(f"Difference: {national_totals['2020-21'] - national_totals['2019-20']:,.0f}")
# Out:
# Checking the actual numbers:
# 2019-20: 3,231,368
# 2020-21: 3,062,348
# Difference: -169,019

# %%
print("Debugging the COVID impact calculation:")
print(f"covid_impact dataframe shape: {covid_impact.shape}")
print(f"States included in covid_impact: {len(covid_impact)}")
print(f"Total pre-COVID from covid_impact: {covid_impact['Pre_COVID'].sum():,.0f}")
print(f"Total during-COVID from covid_impact: {covid_impact['During_COVID'].sum():,.0f}")
print(f"Difference from covid_impact: {covid_impact['Change'].sum():,.0f}")

print("\nCompare to national_totals:")
print(f"2019-20 from national_totals: {national_totals['2019-20']:,.0f}")
print(f"2020-21 from national_totals: {national_totals['2020-21']:,.0f}")

print("\nChecking for missing states in covid_impact:")
states_2019 = set(teachers_clean[teachers_clean['YEAR'] == '2019-20']['STATENAME'])
states_2020 = set(teachers_clean[teachers_clean['YEAR'] == '2020-21']['STATENAME'])
covid_states = set(covid_impact.index)
print(f"States in covid_impact: {len(covid_states)}")
print(f"States in 2019-20 data: {len(states_2019)}")
print(f"States in 2020-21 data: {len(states_2020)}")
# Out:
# Debugging the COVID impact calculation:
# covid_impact dataframe shape: (53, 4)
# States included in covid_impact: 53
# Total pre-COVID from covid_impact: 3,068,297
# Total during-COVID from covid_impact: 3,062,348
# Difference from covid_impact: -5,949
#
# Compare to national_totals:
# 2019-20 from national_totals: 3,231,368
# 2020-21 from national_totals: 3,062,348
#
# Checking for missing states in covid_impact:
# States in covid_impact: 53
# States in 2019-20 data: 56
# States in 2020-21 data: 53

# %%
print("Missing states from covid_impact analysis:")
states_in_2019_not_2020 = states_2019 - states_2020
print(f"States in 2019-20 but not 2020-21: {states_in_2019_not_2020}")

for state in states_in_2019_not_2020:
    teacher_count = teachers_clean[(teachers_clean['YEAR'] == '2019-20') & 
                                 (teachers_clean['STATENAME'] == state)]['STAFF_COUNT'].sum()
    print(f"  {state}: {teacher_count:,.0f} teachers")

total_missing = teachers_clean[(teachers_clean['YEAR'] == '2019-20') & 
                              (teachers_clean['STATENAME'].isin(states_in_2019_not_2020))]['STAFF_COUNT'].sum()
print(f"\nTotal teachers from missing states: {total_missing:,.0f}")
print(f"This explains: {total_missing:,.0f} of the {3231368 - 3068297:,.0f} difference")
# Out:
# Missing states from covid_impact analysis:
# States in 2019-20 but not 2020-21: {'UTAH', 'AMERICAN SAMOA', 'ILLINOIS'}
#   UTAH: 30,256 teachers
#   AMERICAN SAMOA: 0 teachers
#   ILLINOIS: 132,815 teachers
#
# Total teachers from missing states: 163,071
# This explains: 163,071 of the 163,071 difference

# %%
print("Calculating actual COVID impact percentage:")

# Using only the 53 states with consistent reporting
covid_pct_consistent = (covid_impact['Change'].sum() / covid_impact['Pre_COVID'].sum()) * 100
print(f"COVID impact from consistent reporting states: {covid_pct_consistent:.1f}%")

# The misleading calculation (including missing states)
apparent_drop_pct = ((national_totals['2020-21'] - national_totals['2019-20']) / national_totals['2019-20']) * 100
print(f"Apparent drop (including missing state data): {apparent_drop_pct:.1f}%")
# Out:
# Calculating actual COVID impact percentage:
# COVID impact from consistent reporting states: -0.2%
# Apparent drop (including missing state data): -5.2%

# %%
print("Verifying Florida and Utah numbers:")

# Check Florida
florida_2016 = teachers_clean[(teachers_clean['YEAR'] == '2016-17') & 
                             (teachers_clean['STATENAME'] == 'FLORIDA')]['STAFF_COUNT'].sum()
florida_2023 = teachers_clean[(teachers_clean['YEAR'] == '2023-24') & 
                             (teachers_clean['STATENAME'] == 'FLORIDA')]['STAFF_COUNT'].sum()

print(f"Florida 2016-17: {florida_2016:,.0f}")
print(f"Florida 2023-24: {florida_2023:,.0f}")
print(f"Florida change: {florida_2023 - florida_2016:,.0f}")

# Check Utah
utah_2016 = teachers_clean[(teachers_clean['YEAR'] == '2016-17') & 
                          (teachers_clean['STATENAME'] == 'UTAH')]['STAFF_COUNT'].sum()
utah_2023 = teachers_clean[(teachers_clean['YEAR'] == '2023-24') & 
                          (teachers_clean['STATENAME'] == 'UTAH')]['STAFF_COUNT'].sum()

print(f"\nUtah 2016-17: {utah_2016:,.0f}")  
print(f"Utah 2023-24: {utah_2023:,.0f}")
print(f"Utah change: {utah_2023 - utah_2016:,.0f}")

# Check if they have consistent reporting
print(f"\nFlorida years available: {sorted(teachers_clean[teachers_clean['STATENAME'] == 'FLORIDA']['YEAR'].unique())}")
print(f"Utah years available: {sorted(teachers_clean[teachers_clean['STATENAME'] == 'UTAH']['YEAR'].unique())}")
# Out:
# Verifying Florida and Utah numbers:
# Florida 2016-17: 186,339
# Florida 2023-24: 155,800
# Florida change: -30,539
#
# Utah 2016-17: 28,841
# Utah 2023-24: 33,537
# Utah change: 4,696
#
# Florida years available: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
# Utah years available: ['2016-17', '2017-18', '2018-19', '2019-20', '2021-22', '2022-23', '2023-24']

# %%
print("Checking state reporting consistency:")
for state in ['FLORIDA', 'GUAM', 'PUERTO RICO', 'UTAH', 'INDIANA', 'SOUTH CAROLINA']:
    years = sorted(teachers_clean[teachers_clean['STATENAME'] == state]['YEAR'].unique())
    print(f"{state}: {years}")
# Out:
# Checking state reporting consistency:
# FLORIDA: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
# GUAM: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2023-24']
# PUERTO RICO: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
# UTAH: ['2016-17', '2017-18', '2018-19', '2019-20', '2021-22', '2022-23', '2023-24']
# INDIANA: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
# SOUTH CAROLINA: ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']

# %%
# Find states with complete 8-year reporting and their changes
complete_reporting_states = []
for state in state_changes_sorted.index:
    years = teachers_clean[teachers_clean['STATENAME'] == state]['YEAR'].unique()
    if len(years) == 8:  # Complete reporting
        complete_reporting_states.append(state)

complete_changes = state_changes_sorted[state_changes_sorted.index.isin(complete_reporting_states)]

print("States with biggest declines (complete reporting):")
print(complete_changes.head(5)[['Change_Absolute', 'Change_Percent']].round(1))

print("\nStates with biggest increases (complete reporting):")
print(complete_changes.tail(5)[['Change_Absolute', 'Change_Percent']].round(1))
# Out:
# States with biggest declines (complete reporting):
#                      Change_Absolute  Change_Percent
# STATENAME
# U.S. VIRGIN ISLANDS           -246.0           -21.3
# FLORIDA                     -30539.5           -16.4
# PUERTO RICO                  -4308.0           -14.9
# ALASKA                        -603.7            -7.7
# WEST VIRGINIA                 -668.1            -3.5
#
# States with biggest increases (complete reporting):
#                             Change_Absolute  Change_Percent
# STATENAME
# IDAHO                                1761.0            10.9
# INDIANA                              7212.1            12.0
# SOUTH CAROLINA                       6453.4            12.7
# DISTRICT OF COLUMBIA                 1608.2            23.9
# BUREAU OF INDIAN EDUCATION           2903.2             inf
